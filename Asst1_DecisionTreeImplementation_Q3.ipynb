# %% [markdown]
# Decision tree Implementation
# Q3
# The complete code is available in auto-efficiency.py file.
# For the automotive efficiency problem, we implemented and evaluated our decision tree with a maximum depth of 10. The dataset was split into 70% training and 30% testing. Before training, rows with missing horsepower values were removed to ensure data consistency.
#
# Our custom decision tree was then trained on the training data and evaluated on the test set. The results are summarized below:
#
# Part (a): Custom Decision Tree (Regression)
# RMSE: 3.238440317227886
# MAE : 2.3002925746569813
#
# Part (b): Sklearn Decision Tree Regressor
# RMSE: 3.481098466821167
# MAE : 2.4364507667473774
#
# Since the maximum depth was kept the same for both implementations, the close RMSE and MAE values indicate that our decision tree is functioning correctly and yields results comparable to the scikit-learn model.
#
# Additionally, we plotted the performance of both models across different tree depths, showing how the rmse varies with depth.  We see that our model performs close to the Sklearn model and even better at higher depths.

# %%
# %run auto-efficiency.py
# Out:
# Part (a): Custom Decision Tree (Regression)
# RMSE: 3.238440317227886
# MAE : 2.3002925746569813
# Part (b): Sklearn Decision Tree Regressor
# RMSE: 3.481098466821167
# MAE : 2.4364507667473774
# Comparing the predictions at the optimal depth of both the trees

# %% [markdown]
# The above optimal depth that we found is the best depth under 10.

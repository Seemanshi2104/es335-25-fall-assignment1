# %% [markdown]
# Decision tree Implementation
# Q2. Generate your dataset using the given lines of code.
#
# a) Show the usage of your decision tree on the above dataset. The first 70% of the data should be used for training purposes and the remaining 30% for test purposes. Show the accuracy, per-class precision and recall of the decision tree you implemented on the test dataset.
#
# b) Use 5 fold cross-validation on the dataset. Using nested cross-validation find the optimum depth of the tree.
#
# You should be editing classification-exp.py for the code containing the above experiments.

# %% [markdown]
# The complete code is available in classification-exp.py
# Approach:
# For part (a), we generated a 2D synthetic classification dataset using make_classification. The data was first shuffled and then split into training and test sets with a 70/30 ratio. We trained our custom DecisionTree (with information gain as the criterion) on the training data and evaluated it on the test set. The results were reported using accuracy, precision, and recall for each class.
#
# For part (b), we applied nested cross-validation to perform model selection for the decision tree depth. In each outer fold, the training set was further split into inner folds where candidate depths (1–8) were evaluated. The depth giving the highest average validation accuracy was selected, and a new tree was trained with that depth to evaluate on the held-out outer test set. This ensures an unbiased estimate of generalization performance while also identifying the most suitable tree depth.

# %%
# %run classification-exp.py
# Out:
# === Part (a): Results on Test Data (70/30 split) ===
# Accuracy: 0.9666666666666667
# Class 1: Precision=0.947, Recall=1.000
# Class 0: Precision=1.000, Recall=0.917
#
# === Nested Cross-Validation Results ===
# Fold     Best Depth   Outer Accuracy  Val Accuracies
# 1        1            0.900           1:0.89, 2:0.86, 3:0.84, 4:0.81, 5:0.81, 6:0.80, 7:0.80, 8:0.80
# 2        2            0.850           1:0.89, 2:0.91, 3:0.90, 4:0.89, 5:0.88, 6:0.88, 7:0.88, 8:0.88
# 3        1            0.850           1:0.89, 2:0.89, 3:0.88, 4:0.84, 5:0.82, 6:0.81, 7:0.81, 8:0.81
# 4        1            0.950           1:0.90, 2:0.90, 3:0.85, 4:0.85, 5:0.85, 6:0.85, 7:0.85, 8:0.85
# 5        1            0.900           1:0.88, 2:0.86, 3:0.84, 4:0.84, 5:0.82, 6:0.81, 7:0.80, 8:0.80
#
# === Overall Summary ===
# Average outer test accuracy: 0.89
# Depths chosen in each fold: [1, 2, 1, 1, 1]
# Most frequently chosen depth: 1
